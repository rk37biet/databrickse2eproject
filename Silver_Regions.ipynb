# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.read.table("databricks_cata.bronze.regions")
display(df)

# %%
df = df.drop("_rescued_data")
display(df)

# %%
df.write.format("delta")\
        .mode("overwrite")\
        .save("abfss://silver@databricksend2end.dfs.core.windows.net/regions")

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_cata.silver.regions
USING DELTA
LOCATION 'abfss://silver@databricksend2end.dfs.core.windows.net/regions'

# %%
# %sql
SELECT * FROM databricks_cata.silver.regions
